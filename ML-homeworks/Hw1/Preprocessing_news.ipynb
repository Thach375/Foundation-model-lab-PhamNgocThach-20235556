# %% [markdown]
# # Pre-processing News Data

# %% [markdown]
# ## Bài toán
# Dữ liệu gồm n văn bản phân vào 10 chủ đề khác nhau. Cần biễu diễn mỗi văn bản dưới dạng một vector số thể hiện cho nội dụng của văn bản đó.

# %% [markdown]
# ## Mục lục
# - Load dữ liệu từ thư mục
# - Loại bỏ các stop words
# - Sử dụng thư viện để mã hóa TF-IDF cho mỗi văn bản

# %% [markdown]
# ## Phương pháp mã hóa: TF-IDF
# Cho tập gồm $n$ văn bản: $D = \{d_1, d_2, ... d_n\}$. Tập từ điển tương ứng được xây dựng từ $n$ văn bản này có độ dài là $m$
# - Xét văn bản $d$ có $|d|$ từ và $t$ là một từ trong $d$. Mã hóa tf-idf của $t$ trong văn bản $d$ được biểu diễn:
# \begin{equation}
#     \begin{split}
#         \text{tf}_{t, d} &= \frac{f_t}{|d|} \\
#         \text{idf}_{t, d} &= \log\frac{n}{n_t}, \ \ \ \ n_t = |\{d\in D: t\in d\}| \\
#         \text{tf-idf}_{t d} &= \text{tf}_{t, d} \times \text{idf}_{t, d}
#     \end{split}
# \end{equation}
#
# - Khi đó văn bản $d$ được mã hóa là một vector $m$ chiều. Các từ xuất hiện trong d sẽ được thay bằng giá trị tf-idf tương ứng. Các từ không xuất hiện trong $d$ thì thay là 0

# %%
import os
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import load_files
from pyvi import ViTokenizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import Pipeline

# %matplotlib inline

# %% [markdown]
# ## Load dữ liệu từ thư mục
#
# Cấu trúc thư mục như sau
#
# - data/news_vnexpress/
#
#     - Kinh tế:
#         - bài báo 1.txt
#         - bài báo 2.txt
#     - Pháp luật
#         - bài báo 3.txt
#         - bài báo 4.txt

# %%
INPUT = 'news_vnexpress/'
os.makedirs("images",exist_ok=True)  # thư mục lưu các các hình ảnh trong quá trình huấn luyện và đánh gía
print(os.listdir(INPUT))
# Out:
# ['Bản sao của news_1135.zip', 'doi-song', 'du-lich', 'giai-tri', 'giao-duc', 'khoa-hoc', 'kinh-doanh', 'phap-luat', 'suc-khoe', 'the-thao', 'thoi-su']

# %%
# statistics
print('Các nhãn và số văn bản tương ứng trong dữ liệu')
print('----------------------------------------------')
n = 0
for label in os.listdir(INPUT):
    label_path = os.path.join(INPUT, label)
    if os.path.isdir(label_path):
        print(f'{label}: {len(os.listdir(label_path))}')
        n += len(os.listdir(label_path))

print('-------------------------')
print(f"Tổng số văn bản: {n}")
# Out:
# Các nhãn và số văn bản tương ứng trong dữ liệu
# ----------------------------------------------
# doi-song: 120
# du-lich: 54
# giai-tri: 201
# giao-duc: 105
# khoa-hoc: 144
# kinh-doanh: 262
# phap-luat: 59
# suc-khoe: 162
# the-thao: 173
# thoi-su: 59
# -------------------------
# Tổng số văn bản: 1339

# %%
# load data
data_train = load_files(container_path=INPUT, encoding="utf-8")
print('mapping:')
for i in range(len(data_train.target_names)):
    print(f'{data_train.target_names[i]} - {i}')

print('--------------------------')
print(data_train.filenames[0:1])
# print(data_train.data[0:1])
print(data_train.target[0:1])
print(data_train.data[0:1])

print("\nTổng số  văn bản: {}" .format( len(data_train.filenames)))
# Out:
# mapping:
# doi-song - 0
# du-lich - 1
# giai-tri - 2
# giao-duc - 3
# khoa-hoc - 4
# kinh-doanh - 5
# phap-luat - 6
# suc-khoe - 7
# the-thao - 8
# thoi-su - 9
# --------------------------
# ['news_vnexpress/khoa-hoc\\00133.txt']
# [4]
# ['Mời độc giả đặt câu hỏi tại đây\n']
#
# Tổng số  văn bản: 1339

# %% [markdown]
# ## Chuyển dữ liệu dạng text về ma trận (n x m) bằng TF-IDF

# %% [markdown]
# * Bạn cần viết đoạn mã tương ứng trong cell bên dưới. Theo các bước được gợi ý

# %%
# load dữ liệu các stopwords 
#---> Code ở đây
with open('crawl_data/vietnamese-stopwords.txt', 'r', encoding='utf-8') as f:
    stopwords = f.read().splitlines()
stopwords = [x.strip().replace(" ", "_") for x in stopwords] 

# Chuyển hoá dữ liệu text về dạng vector TF 
module_count_vector = CountVectorizer(stop_words=stopwords)
module_tfidf_transformer = TfidfTransformer()

# Hàm thực hiện chuyển đổi dữ liệu text thành dữ liệu số dạng ma trận 
# Input: Dữ liệu 2 chiều dạng numpy.array, mảng nhãn id dạng numpy.array 

def preprocess_data(data_text):
    # Tokenization
    
    data_tokenized = [ViTokenizer.tokenize(text) for text in data_text]
    
    # Chuyển đổi dữ liệu text sang dạng ma trận TF
    X_counts = module_count_vector.fit_transform(data_tokenized)
    
    # Chuyển đổi ma trận TF sang ma trận TF-IDF
    X_tfidf = module_tfidf_transformer.fit_transform(X_counts)
    
    return X_tfidf

data_preprocessed = preprocess_data(data_train.data)

X = data_preprocessed # thuoc tinh
Y = data_train.target #nhan

print(f"\nSố lượng từ trong từ điển: {len(module_count_vector.vocabulary_)}")
print(f"Kích thước dữ liệu sau khi xử lý: {X.shape}")
print(f"Kích thước nhãn tương ứng: {Y.shape}")
# Out:
# Số lượng từ trong từ điển: 24350
# Kích thước dữ liệu sau khi xử lý: (1339, 24350)
# Kích thước nhãn tương ứng: (1339,)

# %%
print(X[100].toarray())
print(Y[100])
# Out:
# [[0. 0. 0. ... 0. 0. 0.]]
# 5

# %%
sum(sum(X[100].toarray() != 0))
# Out:
# np.int64(217)

# %%
print(X[100])
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 217 stored elements and shape (1, 24350)>
#   Coords	Values
#   (0, 78)	0.015478703397323663
#   (0, 97)	0.021134250221654934
#   (0, 153)	0.023671358001332393
#   (0, 185)	0.04805423414913507
#   (0, 266)	0.03382405090314814
#   (0, 386)	0.025219032877002084
#   (0, 391)	0.03483406741576265
#   (0, 412)	0.04977704283322189
#   (0, 656)	0.023169757707443596
#   (0, 902)	0.03376491200960838
#   (0, 1221)	0.05206883654806034
#   (0, 1247)	0.10413767309612068
#   (0, 1260)	0.05206883654806034
#   (0, 1745)	0.04722759863952526
#   (0, 1792)	0.026931200395042987
#   (0, 1970)	0.07618781961894648
#   (0, 2114)	0.05206883654806034
#   (0, 2393)	0.07445161124035883
#   (0, 2586)	0.030026550146382367
#   (0, 2755)	0.04602061487260788
#   (0, 3040)	0.029743417719199822
#   (0, 3178)	0.033058969499355634
#   (0, 3186)	0.045713644403010366
#   (0, 3330)	0.034550934988580105
#   (0, 3641)	0.02631231276425594
#   :	:
#   (0, 22489)	0.025901791695506483
#   (0, 22504)	0.02933927731449147
#   (0, 22533)	0.032418288350799136
#   (0, 22540)	0.164193837352696
#   (0, 22586)	0.08889820390904644
#   (0, 22694)	0.0216328443255132
#   (0, 22997)	0.05331834821051842
#   (0, 23237)	0.026931200395042987
#   (0, 23257)	0.027817824705684224
#   (0, 23297)	0.07529256947983896
#   (0, 23384)	0.05245648331652003
#   (0, 23396)	0.034550934988580105
#   (0, 23456)	0.04090612713363008
#   (0, 23458)	0.03146669137463949
#   (0, 23502)	0.1777964078180929
#   (0, 23618)	0.037225805620179415
#   (0, 23626)	0.10205686822329722
#   (0, 23633)	0.037225805620179415
#   (0, 23689)	0.04337994654836895
#   (0, 23732)	0.028199616254834473
#   (0, 23846)	0.036829367360986104
#   (0, 23960)	0.030474175215936126
#   (0, 23987)	0.07928316937028587
#   (0, 24136)	0.032838767470539196
#   (0, 24167)	0.052126192411498316
